# %%
import polars as pl

aadr = pl.read_excel("Dataset/AADR.xlsx")
aadr = aadr.rename({"Date mean in BP in years before 1950 CE [OxCal mu for a direct radiocarbon date, and average of range for a contextual date]": "Date"})
aadr.schema
# Out:
# Schema([('#', Int64),
#         ('Genetic ID', String),
#         ('Master ID', String),
#         ('Skeletal code', String),
#         ('Skeletal element', String),
#         ('Year data from this individual was first published [for a present-day individuals we give the data of the data reported here; missing GreenScience 2010 (Vi33.15, Vi33.26), Olalde2018 (I2657), RasmussenNature2010 (Australian)]',
#          String),
#         ('Publication', String),
#         ('Method for Determining Date; unless otherwise specified, calibrations use 95.4% intervals from OxCal v4.4.2 Bronk Ramsey (2009); r5; Atmospheric data from Reimer et al (2020)',
#          String),
#         ('Date', Int64),
#         ('Date standard deviation in BP [OxCal sigma for a direct radiocarbon date, and standard deviation of the uniform distribution between the two bounds for a contextual date]',
#          Int64),
#         ('Full Date One of two formats. (Format 1) 95.4% CI calibrated radiocarbon age (Conventional Radiocarbon Age BP, Lab number) e.g. 2624-2350 calBCE (3990±40 BP, Ua-35016). (Format 2) Archaeological context range, e.g. 2500-1700 BCE',
#          String),
#         ('Age at Death from physical anthropology', String),
#         ('Group ID', String),
#         ('Locality', String),
#         ('Political Entity', String),
#         ('Lat.', Float64),
#         ('Long.', Float64),
#         ('Pulldown Strategy', String),
#         ('Data source', String),
#         ('No. Libraries', String),
#         ('1240k coverage (taken from original pulldown where possible)',
#          String),
#         ('SNPs hit on autosomal targets (Computed using easystats on 1240k snpset)',
#          Int64),
#         ('SNPs hit on autosomal targets (Computed using easystats on HO snpset)',
#          Int64),
#         ('Molecular Sex', String),
#         ('Family ID and position within family', String),
#         ('Y haplogroup (manual curation in terminal mutation format)', String),
#         ('Y haplogroup (manual curation in ISOGG format)', String),
#         ('mtDNA coverage (merged data)', String),
#         ('mtDNA haplogroup if >2x or published', String),
#         ('mtDNA match to consensus if >2x (merged data)', String),
#         ('Damage rate in first nucleotide on sequences overlapping 1240k targets (merged data)',
#          String),
#         ('Sex ratio [Y/(Y+X) counts] (merged data)', String),
#         ('Library type (minus=no.damage.correction, half=damage.retained.at.last.position, plus=damage.fully.corrected, ds=double.stranded.library.preparation, ss=single.stranded.library.preparation)',
#          String),
#         ('Libraries', String),
#         ('ASSESSMENT', String),
#         ('ASSESSMENT WARNINGS (Xcontam interval is listed if lower bound is >0.005, "QUESTIONABLE" if lower bound is 0.01-0.02, "QUESTIONABLE_CRITICAL" or "FAIL" if lower bound is >0.02) (mtcontam confidence interval is listed if coverage >2 and upper bound is <0.',
#          String)])

# %%
gendist = pl.read_excel("Dataset/GeneticDistance_aDNA.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gendist = pl.read_excel("Dataset/GeneticDistance_aDNA.xlsx")
#
# File ~/projects/Population-genetics-heatmap/.venv/lib64/python3.14/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~/projects/Population-genetics-heatmap/.venv/lib64/python3.14/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~/projects/Population-genetics-heatmap/.venv/lib64/python3.14/site-packages/polars/io/spreadsheet/functions.py:402, in read_excel(source, sheet_id, sheet_name, table_name, engine, engine_options, read_options, has_header, columns, schema_overrides, infer_schema_length, include_file_paths, drop_empty_rows, drop_empty_cols, raise_if_empty)
#     240 @deprecate_renamed_parameter("xlsx2csv_options", "engine_options", version="0.20.6")
#     241 @deprecate_renamed_parameter("read_csv_options", "read_options", version="0.20.7")
#     242 def read_excel(
#    (...)    258     raise_if_empty: bool = True,
#     259 ) -> pl.DataFrame | dict[str, pl.DataFrame]:
#     260     """
#     261     Read Excel spreadsheet data into a DataFrame.
#     262
#    (...)    400     ... )  # doctest: +SKIP
#     401     """
# --> 402     sources, read_multiple_workbooks = _sources(source)
#     403     frames: list[pl.DataFrame] | list[dict[str, pl.DataFrame]] = [  # type: ignore[assignment]
#     404         _read_spreadsheet(
#     405             src,
#    (...)    421         for src in sources
#     422     ]
#     423     return _unpack_read_results(
#     424         frames=frames,
#     425         read_multiple_workbooks=read_multiple_workbooks,
#     426     )
#
# File ~/projects/Population-genetics-heatmap/.venv/lib64/python3.14/site-packages/polars/io/spreadsheet/functions.py:72, in _sources(source)
#      70     if not files:
#      71         msg = f"no workbook found at path {src!r}"
# ---> 72         raise FileNotFoundError(msg)
#      73     read_multiple_workbooks = True
#      74 else:
#
# FileNotFoundError: no workbook found at path 'Dataset/GeneticDistance_aDNA.xlsx'

# %%
fil = aadr.filter((1950 - pl.col("Date") > 700) & (1950 - pl.col("Date") < 1100) & (pl.col("Group ID").str.contains("Iceland"))).select("Master ID", "Date", "Group ID")
print(fil)
# Out:
# shape: (1_268, 3)
# ┌───────────┬──────┬────────────────────────────┐
# │ Master ID ┆ Date ┆ Group ID                   │
# │ ---       ┆ ---  ┆ ---                        │
# │ str       ┆ i64  ┆ str                        │
# ╞═══════════╪══════╪════════════════════════════╡
# │ I8122     ┆ 1150 ┆ Dominican_ElSoco_Ceramic   │
# │ I17623    ┆ 1050 ┆ Albania_BA_IA_o_lc         │
# │ I13839    ┆ 1014 ┆ Albania_Medieval           │
# │ I14622    ┆ 1121 ┆ Albania_Medieval           │
# │ I14875    ┆ 1073 ┆ Bahamas_AbacoIsl_Ceramic   │
# │ …         ┆ …    ┆ …                          │
# │ A1809     ┆ 1175 ┆ Hungary_DanubeTisza_LAvar  │
# │ A1810     ┆ 1200 ┆ Hungary_DanubeTisza_LAvar  │
# │ A1811     ┆ 1200 ┆ Hungary_DanubeTisza_MLAvar │
# │ A1814     ┆ 1175 ┆ Hungary_DanubeTisza_LAvar  │
# │ A1815     ┆ 1200 ┆ Hungary_DanubeTisza_LAvar  │
# └───────────┴──────┴────────────────────────────┘

# %%
target_ID = fil.select("Master ID").unique()
gendist_prep = gendist.with_columns([pl.col("SampleID1").is_in(target_ID["Master ID"]).alias("s1_matched"), pl.col("SampleID2").is_in(target_ID["Master ID"]).alias("s2_matched")])
print(gendist_prep)
# Out:
# shape: (54_287, 5)
# ┌───────────┬───────────┬──────┬────────────┬────────────┐
# │ SampleID1 ┆ SampleID2 ┆ Dist ┆ s1_matched ┆ s2_matched │
# │ ---       ┆ ---       ┆ ---  ┆ ---        ┆ ---        │
# │ str       ┆ str       ┆ f64  ┆ bool       ┆ bool       │
# ╞═══════════╪═══════════╪══════╪════════════╪════════════╡
# │ DAV-A8    ┆ DAV-A9    ┆ 0.79 ┆ true       ┆ true       │
# │ DAV-A8    ┆ DKS-A1    ┆ 1.0  ┆ true       ┆ true       │
# │ DAV-A8    ┆ FOV-A1    ┆ 0.79 ┆ true       ┆ false      │
# │ DAV-A8    ┆ FSS-A1    ┆ 0.99 ┆ true       ┆ true       │
# │ DAV-A8    ┆ GRS-A1    ┆ 0.99 ┆ true       ┆ true       │
# │ …         ┆ …         ┆ …    ┆ …          ┆ …          │
# │ EDM176.SG ┆ L6103.AG  ┆ 0.68 ┆ false      ┆ false      │
# │ EDM176.SG ┆ L6101.AG  ┆ 0.67 ┆ false      ┆ false      │
# │ 11KBM1.SG ┆ L6103.AG  ┆ 0.87 ┆ false      ┆ false      │
# │ 11KBM1.SG ┆ L6101.AG  ┆ 0.88 ┆ false      ┆ false      │
# │ L6103.AG  ┆ L6101.AG  ┆ 0.96 ┆ false      ┆ false      │
# └───────────┴───────────┴──────┴────────────┴────────────┘
# /tmp/ipykernel_51871/3295285087.py:2: DeprecationWarning: `is_in` with a collection of the same datatype is ambiguous and deprecated.
# Please use `implode` to return to previous behavior.
#
# See https://github.com/pola-rs/polars/issues/22149 for more information.
#   gendist_prep = gendist.with_columns([pl.col("SampleID1").is_in(target_ID["Master ID"]).alias("s1_matched"), pl.col("SampleID2").is_in(target_ID["Master ID"]).alias("s2_matched")])

# %%
gendist_prep = gendist_prep.with_columns(
    pl.when(pl.col("s1_matched"))
    .then(pl.col("SampleID2")) # col1 matched, use col2
    .when(pl.col("s2_matched"))
    .then(pl.col("SampleID1")) # col2 matched, use col1
    .otherwise(None)      # Both matched or neither matched -> No Join
    .alias("join_key")
)

# %%
Extend_tab = gendist_prep.join(
    aadr,
    left_on="join_key",
    right_on="Master ID", 
    how="inner"
).select(["SampleID1", "SampleID2", "Dist", "join_key", "Date", "Group ID", "Lat.", "Long."])

# %%
Extend_tab
# Out:
# shape: (350, 8)
# ┌───────────┬───────────┬──────┬──────────┬──────┬────────────────────────┬───────────┬────────────┐
# │ SampleID1 ┆ SampleID2 ┆ Dist ┆ join_key ┆ Date ┆ Group ID               ┆ Lat.      ┆ Long.      │
# │ ---       ┆ ---       ┆ ---  ┆ ---      ┆ ---  ┆ ---                    ┆ ---       ┆ ---        │
# │ str       ┆ str       ┆ f64  ┆ str      ┆ i64  ┆ str                    ┆ f64       ┆ f64        │
# ╞═══════════╪═══════════╪══════╪══════════╪══════╪════════════════════════╪═══════════╪════════════╡
# │ DAV-A8    ┆ DAV-A9    ┆ 0.79 ┆ DAV-A9   ┆ 950  ┆ Iceland_Pre_Christian. ┆ 65.966667 ┆ -18.533333 │
# │           ┆           ┆      ┆          ┆      ┆ SG_son.D…              ┆           ┆            │
# │ DAV-A8    ┆ DKS-A1    ┆ 1.0  ┆ DKS-A1   ┆ 1025 ┆ Iceland_Pre_Christian. ┆ 64.885055 ┆ -24.04446  │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ DAV-A8    ┆ FOV-A1    ┆ 0.79 ┆ FOV-A1   ┆ 603  ┆ Iceland_Early_Christia ┆ 65.437602 ┆ -14.602639 │
# │           ┆           ┆      ┆          ┆      ┆ n.SG                   ┆           ┆            │
# │ DAV-A8    ┆ FSS-A1    ┆ 0.99 ┆ FSS-A1   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.317    ┆ -19.15     │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ DAV-A8    ┆ GRS-A1    ┆ 0.99 ┆ GRS-A1   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.642222 ┆ -16.120278 │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ …         ┆ …         ┆ …    ┆ …        ┆ …    ┆ …                      ┆ …         ┆ …          │
# │ VDP-A5    ┆ VDP-A7    ┆ 0.91 ┆ VDP-A7   ┆ 1000 ┆ Iceland_Pre_Christian. ┆ 65.5707   ┆ -24.0658   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A5    ┆ YGS-B2    ┆ 0.96 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A6    ┆ VDP-A7    ┆ 0.93 ┆ VDP-A7   ┆ 1000 ┆ Iceland_Pre_Christian. ┆ 65.5707   ┆ -24.0658   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A6    ┆ YGS-B2    ┆ 0.99 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A7    ┆ YGS-B2    ┆ 0.93 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# └───────────┴───────────┴──────┴──────────┴──────┴────────────────────────┴───────────┴────────────┘

# %%
import geopandas as gpd

df_pd = Extend_tab.to_pandas()
gdf = gpd.GeoDataFrame(
    df_pd, geometry=gpd.points_from_xy(df_pd["Long."], df_pd["Lat."]), crs="EPSG:4326"
)

# %%
from geodatasets import get_path
import matplotlib.pyplot as plt

world = gpd.read_file(get_path("naturalearth.land"))
# ax = world.plot(color="white", edgecolor="black")
fig, ax = plt.subplots(figsize=(24, 18))
world.plot(ax=ax, alpha=0.4, color="grey")
gdf.plot(ax=ax, column="Dist", cmap="jet", linewidth=0.4, edgecolor=".4")
plt.show()

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from geodatasets import get_path

world = gpd.read_file(get_path("naturalearth.land"))


fig, ax = plt.subplots(figsize=(10,6))
world.plot(ax=ax, color="lightgrey")

sc = ax.scatter(
    gdf["Long."], gdf["Lat."],
    c=gdf["Dist"],
    cmap="jet",
    s=80
)

plt.colorbar(sc, label="Genetic Distance to Iceland Vikings")
#plt.title(f"Genetic Similarity Map — {t}-{t+100} BP")

plt.savefig("modern.png")
plt.close()
# Out:
# Downloading file 'NUTS_RG_10M_2024_3035.gpkg' from 'https://gisco-services.ec.europa.eu/distribution/v2/nuts/gpkg/NUTS_RG_10M_2024_3035.gpkg' to '/home/inf-43-2025/.cache/geodatasets'.

# %%
Extend_tab
# Out:
# shape: (350, 8)
# ┌───────────┬───────────┬──────┬──────────┬──────┬────────────────────────┬───────────┬────────────┐
# │ SampleID1 ┆ SampleID2 ┆ Dist ┆ join_key ┆ Date ┆ Group ID               ┆ Lat.      ┆ Long.      │
# │ ---       ┆ ---       ┆ ---  ┆ ---      ┆ ---  ┆ ---                    ┆ ---       ┆ ---        │
# │ str       ┆ str       ┆ f64  ┆ str      ┆ i64  ┆ str                    ┆ f64       ┆ f64        │
# ╞═══════════╪═══════════╪══════╪══════════╪══════╪════════════════════════╪═══════════╪════════════╡
# │ DAV-A8    ┆ DAV-A9    ┆ 0.79 ┆ DAV-A9   ┆ 950  ┆ Iceland_Pre_Christian. ┆ 65.966667 ┆ -18.533333 │
# │           ┆           ┆      ┆          ┆      ┆ SG_son.D…              ┆           ┆            │
# │ DAV-A8    ┆ DKS-A1    ┆ 1.0  ┆ DKS-A1   ┆ 1025 ┆ Iceland_Pre_Christian. ┆ 64.885055 ┆ -24.04446  │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ DAV-A8    ┆ FOV-A1    ┆ 0.79 ┆ FOV-A1   ┆ 603  ┆ Iceland_Early_Christia ┆ 65.437602 ┆ -14.602639 │
# │           ┆           ┆      ┆          ┆      ┆ n.SG                   ┆           ┆            │
# │ DAV-A8    ┆ FSS-A1    ┆ 0.99 ┆ FSS-A1   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.317    ┆ -19.15     │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ DAV-A8    ┆ GRS-A1    ┆ 0.99 ┆ GRS-A1   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.642222 ┆ -16.120278 │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ …         ┆ …         ┆ …    ┆ …        ┆ …    ┆ …                      ┆ …         ┆ …          │
# │ VDP-A5    ┆ VDP-A7    ┆ 0.91 ┆ VDP-A7   ┆ 1000 ┆ Iceland_Pre_Christian. ┆ 65.5707   ┆ -24.0658   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A5    ┆ YGS-B2    ┆ 0.96 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A6    ┆ VDP-A7    ┆ 0.93 ┆ VDP-A7   ┆ 1000 ┆ Iceland_Pre_Christian. ┆ 65.5707   ┆ -24.0658   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A6    ┆ YGS-B2    ┆ 0.99 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# │ VDP-A7    ┆ YGS-B2    ┆ 0.93 ┆ YGS-B2   ┆ 1015 ┆ Iceland_Pre_Christian. ┆ 65.9016   ┆ -18.5984   │
# │           ┆           ┆      ┆          ┆      ┆ SG                     ┆           ┆            │
# └───────────┴───────────┴──────┴──────────┴──────┴────────────────────────┴───────────┴────────────┘

# %%
import folium 
from folium import plugins

map = folium.Map(location=[15, 30], tiles="Cartodb dark_matter", zoom_start=2)

heat_data = [
    [point.xy[1][0], point.xy[0][0], dist]
    for point, dist in zip(gdf.geometry, gdf["Dist"])
]

heat_data
plugins.HeatMap(heat_data, radius=25, blur=20, max_zoom=5).add_to(map)

map.save("Iceland.html")
